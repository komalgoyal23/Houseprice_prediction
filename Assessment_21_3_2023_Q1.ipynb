# %% [markdown]
# <a href="https://colab.research.google.com/github/komalgoyal23/Houseprice_prediction/blob/main/Assessment_21_3_2023_Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/car_details_from_car_dekho - car_details_from_car_dekho.csv")
df
# Out:
#                      name  year  selling_price  km_driven    fuel seller_type  \
# 0           Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 1    Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 2   Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
# 3           Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 4    Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 5   Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
# 6   Honda Amaze VX i-DTEC  2013         500000      30000  Diesel  Individual
# 7           Maruti 800 AC  2007          95000     100000  Petrol  Individual
# 8           Maruti 800 AC  2002          65000     100000  Petrol  Individual
# 9           Maruti 800 AC  2000          60000      40000  Petrol  Individual
# 10          Maruti 800 AC  2007         105000      60000  Petrol  Individual
# ...

# %%
df.head()
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 0          Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 1   Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 2  Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
# 3          Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 4   Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
#
#   transmission         owner
# 0       Manual   First Owner
# 1       Manual   First Owner
# 2       Manual  Second Owner
# 3       Manual   First Owner
# 4       Manual   First Owner

# %% [markdown]
# #3. REMOVE COLUMN OF SAME VALUE

# %%
df=df.drop(["transmission"], axis=1)

# %%
df.head()
# Out:
#                     name  year  selling_price  km_driven    fuel seller_type  \
# 0          Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 1   Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
# 2  Honda Amaze VX i-DTEC  2014         450000     141000  Diesel  Individual
# 3          Maruti 800 AC  2007          60000      70000  Petrol  Individual
# 4   Hyundai Verna 1.6 SX  2012         600000     100000  Diesel  Individual
#
#           owner
# 0   First Owner
# 1   First Owner
# 2  Second Owner
# 3   First Owner
# 4   First Owner

# %% [markdown]
# #4. Set selling price as target coloumn

# %%
 
x = df.drop(['selling_price'],axis=1).values
y = df['selling_price'].values

# %% [markdown]
# #5. Split 90:10

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=0)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.1)
df

# %% [markdown]
# #Ordinal encoder

# %%
df["owner"].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder
od_value=['First Owner', 'Second Owner', 'Third Owner',
       'Fourth & Above Owner']
ordi=OrdinalEncoder(categories=[od_value])
ordi.fit(x_train[["owner"]])
pd.DataFrame(ordi.transform(x_train[["owner"]]))
